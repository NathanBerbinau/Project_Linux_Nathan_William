# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from xgboost import XGBRegressor
import statsmodels.api as sm

# %%
# Out:
# 2025-11-20 18:40:24.542 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-20 18:40:24.555 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
# Out:
# 2025-11-20 18:44:02.443 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.639
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\natha\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-20 18:44:02.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.663 Session state does not function when running a script without `streamlit run`
# 2025-11-20 18:44:02.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.682 No runtime found, using MemoryCacheStorageManager
# 2025-11-20 18:44:02.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:02.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:03.198 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:03.200 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.282 No runtime found, using MemoryCacheStorageManager
# 2025-11-20 18:44:06.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\natha\AppData\Local\Temp\ipykernel_14116\2836122907.py:45: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period=period, progress=False)
# 2025-11-20 18:44:06.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-20 18:44:06.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
